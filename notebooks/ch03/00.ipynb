# %%
import pandas as pd
orders = pd.read_csv("../../data/raw/orders.csv")
# orders = DataFrame
# 데이터를 선택·필터링·집계·변환을 하기 위해 DataFrame을 사용한다.

orders.info()
#.ipynb에서는 print() 안해도 자동으로 출력됨 .py에서는 지켜줘야함

orders.columns   # orders csv의 컬럼들만 리스트 형식으로 출력

orders.dtypes
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   order_id        300 non-null    int64
#  1   customer_id     300 non-null    int64
#  2   order_date      300 non-null    str
#  3   payment_method  300 non-null    str
#  4   order_status    300 non-null    str
# dtypes: int64(2), str(3)
# memory usage: 11.8 KB
# order_id          int64
# customer_id       int64
# order_date          str
# payment_method      str
# order_status        str
# dtype: object

# %%
print(orders.head())    # 상위 5개

print(orders.tail())    # 하위 5개
# Out:
#    order_id  customer_id  order_date payment_method order_status
# 0         1          123  2026-07-02           card    completed
# 1         2           77  2025-09-17      naver_pay    cancelled
# 2         3          138  2026-01-14  bank_transfer    cancelled
# 3         4           57  2026-03-27      kakao_pay    cancelled
# 4         5          125  2026-02-15           card    cancelled
#      order_id  customer_id  order_date payment_method order_status
# 295       296          116  2026-03-30           card    completed
# 296       297           22  2026-03-12  bank_transfer    completed
# 297       298           64  2026-02-19      naver_pay    cancelled
# 298       299          135  2025-10-03  bank_transfer    completed
# 299       300           96  2026-04-22      kakao_pay    cancelled

# %%
print(orders.index)
cid = orders["order_id"]

print(type(cid)) # 컬럼이 하나기 때문에 cid는 Series 타입이다.   # 컬럼 두개 이상은 DataFrame 타입이 된다.
print(cid)

df = orders[["customer_id", "order_id"]]
print(df)

df = orders[["customer_id"]]    # 리스트 형식이기 때문에 이건 컬럼이 하나여도 DataFrame이다.
print(df)
# Out:
# RangeIndex(start=0, stop=300, step=1)
# <class 'pandas.Series'>
# 0        1
# 1        2
# 2        3
# 3        4
# 4        5
#       ...
# 295    296
# 296    297
# 297    298
# 298    299
# 299    300
# Name: order_id, Length: 300, dtype: int64
#      customer_id  order_id
# 0            123         1
# 1             77         2
# 2            138         3
# 3             57         4
# 4            125         5
# ..           ...       ...
# 295          116       296
# 296           22       297
# 297           64       298
# 298          135       299
# 299           96       300
#
# [300 rows x 2 columns]

# %%
print(orders.describe())
# Out:
#          order_id  customer_id
# count  300.000000   300.000000
# mean   150.500000    79.490000
# std     86.746758    43.780807
# min      1.000000     3.000000
# 25%     75.750000    38.000000
# 50%    150.500000    83.000000
# 75%    225.250000   116.250000
# max    300.000000   149.000000

# %%
print(orders["order_status"])
print("--------------------------------------------------------")
print(orders["order_status"].value_counts(dropna=False))    # 184 + 64 + 52 = 300으로 결측치(null값) 없음 확인 가능
# Out:
# 0      completed
# 1      cancelled
# 2      cancelled
# 3      cancelled
# 4      cancelled
#          ...
# 295    completed
# 296    completed
# 297    cancelled
# 298    completed
# 299    cancelled
# Name: order_status, Length: 300, dtype: str
# --------------------------------------------------------
# order_status
# completed    184
# cancelled     64
# refunded      52
# Name: count, dtype: int64
